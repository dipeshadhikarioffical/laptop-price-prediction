# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("laptop_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df['Ram'] = df['Ram'].str.replace('GB','') # to remove GB from KG

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df['Memory'] = df['Memory'].str.replace('GB', '')
df['Memory'] = df['Memory'].str.replace('TB', '000')
new = df['Memory'].str.split("+", n=1, expand = True)

df['first'] = new[0]
df['first'] = df["first"].str.strip()

df['second'] = new[1]

df['Layer1HDD'] = df['first'].apply(lambda x: 1 if "HDD" in x else 0)
df['Layer1SSD'] = df['first'].apply(lambda x: 1 if "SSD" in x else 0)
df['Layer1Hybrid'] = df['first'].apply(lambda x: 1 if "Hybrid" in x else 0)
df['Layer1Flash_Storage'] = df['first'].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['fist'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df['Layer2HDD'] = df['second'].apply(lambda x: 1 if "HDD" in x else 0)
df['Layer2SSD'] = df['second'].apply(lambda x: 1 if "SSD" in x else 0)
df['Layer2Hybrid'] = df['second'].apply(lambda x: 1 if "Hybrid" in x else 0)
df['Layer2Flash_Storage'] = df['second'].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df['HDD'] = (df['first'] * df['Layer1HDD'] + df['second'] * df['Layer2HDD'])
df['SSD'] = (df['first'] * df['Layer1SSD'] + df['second'] * df['Layer2SSD'])
df['Hybrid'] = (df['first'] * df['Layer1Hybrid'] + df['second'] * df['Layer2Hybrid'])
df['Flash_Storage'] = (df['first'] * df['Layer1Flash_Storage'] + df['second'] * df['Layer2Flash_Storage'])
# Out:
# C:\PROGRA~1\KMSpico\temp/ipykernel_4220/2382613864.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['fist'] = df['first'].str.replace(r'\D', '')
# C:\PROGRA~1\KMSpico\temp/ipykernel_4220/2382613864.py:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.sample(10)
# Out:
#      Company            TypeName  Inches                 ScreenResolution  \
# 226     Dell            Notebook    15.6  Full HD / Touchscreen 1920x1080
# 306       HP  2 in 1 Convertible    13.3  Full HD / Touchscreen 1920x1080
# 627   Lenovo            Notebook    15.6                Full HD 1920x1080
# 956     Dell  2 in 1 Convertible    13.3  Full HD / Touchscreen 1920x1080
# 883   Lenovo            Notebook    15.6      IPS Panel Full HD 1920x1080
# 391     Asus              Gaming    17.3                Full HD 1920x1080
# 408   Lenovo            Notebook    15.6                Full HD 1920x1080
# 1132    Asus            Notebook    14.0                         1366x768
# 56        HP            Notebook    15.6                Full HD 1920x1080
# 849       HP           Ultrabook    14.0                Full HD 1920x1080
#
#                                        Cpu Ram               Memory  \
# 226             Intel Core i7 7500U 2.7GHz  16             1000 HDD
# ...

# %%
df['HDD'] = df['HDD'].str.replace(r'\D', '')
df['SSD'] = df['SSD'].str.replace(r'\D', '')
df['Hybrid'] = df['Hybrid'].str.replace(r'\D', '')
df['Flash_Storage'] = df['Flash_Storage'].str.replace(r'\D', '')
# Out:
# C:\PROGRA~1\KMSpico\temp/ipykernel_4220/2524749382.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['HDD'] = df['HDD'].str.replace(r'\D', '')
# C:\PROGRA~1\KMSpico\temp/ipykernel_4220/2524749382.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['SSD'] = df['SSD'].str.replace(r'\D', '')
# C:\PROGRA~1\KMSpico\temp/ipykernel_4220/2524749382.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Hybrid'] = df['Hybrid'].str.replace(r'\D', '')
# C:\PROGRA~1\KMSpico\temp/ipykernel_4220/2524749382.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Flash_Storage'] = df['Flash_Storage'].str.replace(r'\D', '')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram             Memory  \
# 0        Intel Core i5 2.3GHz   8            128 SSD
# 1        Intel Core i5 1.8GHz   8  128 Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256 SSD
# 3        Intel Core i7 2.7GHz  16            512 SSD
# 4        Intel Core i5 3.1GHz   8            256 SSD
#
#                             Gpu  OpSys  Weight  ...  Layer1Flash_Storage fist  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  ...                    0  128
# 1        Intel HD Graphics 6000  macOS  1.34kg  ...                    1  128
# ...
